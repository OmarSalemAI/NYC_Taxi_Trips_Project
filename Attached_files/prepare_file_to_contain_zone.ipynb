# %%
import pandas as pd

df = pd.read_parquet('yellow_tripdata_2009-02.parquet')

df.head()
# Out:
#   vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0         DDS  2009-02-03 08:25:00   2009-02-03 08:33:39                1
# 1         VTS  2009-02-28 00:26:00   2009-02-28 00:40:00                5
# 2         DDS  2009-02-22 00:39:23   2009-02-22 00:45:52                1
# 3         VTS  2009-02-28 12:47:00   2009-02-28 12:54:00                1
# 4         DDS  2009-02-05 18:34:35   2009-02-05 18:43:26                1
#
#    Trip_Distance  Start_Lon  Start_Lat  Rate_Code  store_and_forward  \
# 0           1.60 -73.992768  40.758325        NaN                NaN
# 1           3.05   0.000000   0.000000        NaN                NaN
# 2           1.50 -73.137393  41.366138        NaN                NaN
# 3           1.42 -73.980458  40.748445        NaN                NaN
# 4           1.50 -73.137393  41.366138        NaN                NaN
#
#      End_Lon    End_Lat Payment_Type  Fare_Amt  surcharge  mta_tax  Tip_Amt  \
# 0 -73.994710  40.739723         CASH       6.9        0.0      NaN      0.0
# 1   0.000000   0.000000         CASH      10.5        0.5      NaN      0.0
# 2 -73.137393  41.366138         CASH       5.7        0.5      NaN      0.0
# 3 -73.996103  40.737095         CASH       6.1        0.0      NaN      0.0
# 4 -73.137393  41.366138         CASH       6.9        1.0      NaN      0.0
#
#    Tolls_Amt  Total_Amt
# 0        0.0        6.9
# 1        0.0       11.0
# 2        0.0        6.2
# 3        0.0        6.1
# 4        0.0        7.9

# %%
print(df['store_and_forward'].value_counts(dropna=False))
# Out:
# store_and_forward
# NaN    9009801
# 0.0    4268846
# 1.0     101475
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# vendor_name                     0
# Trip_Pickup_DateTime            0
# Trip_Dropoff_DateTime           0
# Passenger_Count                 0
# Trip_Distance                   0
# Start_Lon                       0
# Start_Lat                       0
# Rate_Code                13380122
# store_and_forward         9009801
# End_Lon                         0
# End_Lat                         0
# Payment_Type                    0
# Fare_Amt                        0
# surcharge                       0
# mta_tax                  13380122
# Tip_Amt                         0
# Tolls_Amt                       0
# Total_Amt                       0
# dtype: int64

# %%
len(df)
# Out:
# 13380122

# %%
print(df['Payment_Type'].value_counts(dropna=False))
# Out:
# Payment_Type
# CASH         5573418
# Cash         4623482
# Credit       2970754
# CREDIT        161720
# No Charge      42024
# Dispute         8724
# Name: count, dtype: int64

# %%
import pandas as pd
import geopandas as gpd
import pyarrow.parquet as pq
from shapely.geometry import Point

# Load NYC taxi zones shapefile
zones = gpd.read_file(r'F:\Data Engineering Projects\NYC Tax\taxi_zones\taxi_zones.shp')
zones = zones.to_crs(epsg=4326)

# Initialize final result DataFrame
final_df = pd.DataFrame()

# Load the Parquet file in chunks using PyArrow
parquet_file = pq.ParquetFile('yellow_tripdata_2009-02.parquet')

# Loop through batches
for i, batch in enumerate(parquet_file.iter_batches(batch_size=100_000)):
    print(f"Processing batch {i+1}")
    
    # Convert batch to pandas DataFrame
    df = batch.to_pandas()

    # Rename coordinates columns if needed
    df.rename(columns={
        'Start_Lon': 'start_lon',
        'Start_Lat': 'start_lat',
        'End_Lon': 'end_lon',
        'End_Lat': 'end_lat'
    }, inplace=True)

    # Drop missing coordinate rows
    df = df.dropna(subset=['start_lon', 'start_lat', 'end_lon', 'end_lat'])

    # ------------------------------
    # Start Locations → start_zone
    # ------------------------------
    start_points = gpd.GeoDataFrame(
        df.copy(),
        geometry=gpd.points_from_xy(df['start_lon'], df['start_lat']),
        crs='EPSG:4326'
    )
    start_with_zone = gpd.sjoin(start_points, zones, how='left', predicate='within')
    df['start_zone'] = start_with_zone['zone'].values
    df['start_borough'] = start_with_zone['borough'].values

    # ------------------------------
    # End Locations → end_zone
    # ------------------------------
    end_points = gpd.GeoDataFrame(
        df.copy(),
        geometry=gpd.points_from_xy(df['end_lon'], df['end_lat']),
        crs='EPSG:4326'
    )
    end_with_zone = gpd.sjoin(end_points, zones, how='left', predicate='within')
    df['end_zone'] = end_with_zone['zone'].values
    df['end_borough'] = end_with_zone['borough'].values

    # Drop geometry column to reduce memory
    df.drop(columns='geometry', inplace=True, errors='ignore')

    # Append to final DataFrame
    final_df = pd.concat([final_df, df], ignore_index=True)

    print(f"→ Batch {i+1} complete: {len(df)} records processed.")

# Save final enriched dataset to a new Parquet file (optional)
final_df.to_parquet('yellow_tripdata_2009-02_enriched.parquet', index=False)

print(f"\n✅ All done! Total enriched records: {len(final_df)}")
# Out:
# Processing batch 1
# → Batch 1 complete: 100000 records processed.
# Processing batch 2
# → Batch 2 complete: 100000 records processed.
# Processing batch 3
# → Batch 3 complete: 100000 records processed.
# Processing batch 4
# → Batch 4 complete: 100000 records processed.
# Processing batch 5
# → Batch 5 complete: 100000 records processed.
# Processing batch 6
# → Batch 6 complete: 100000 records processed.
# Processing batch 7
# → Batch 7 complete: 100000 records processed.
# Processing batch 8
# → Batch 8 complete: 100000 records processed.
# Processing batch 9
# → Batch 9 complete: 100000 records processed.
# Processing batch 10
# → Batch 10 complete: 100000 records processed.
# Processing batch 11
# → Batch 11 complete: 100000 records processed.
# Processing batch 12
# → Batch 12 complete: 100000 records processed.
# Processing batch 13
# → Batch 13 complete: 100000 records processed.
# Processing batch 14
# → Batch 14 complete: 100000 records processed.
# Processing batch 15
# → Batch 15 complete: 100000 records processed.
# Processing batch 16
# → Batch 16 complete: 100000 records processed.
# Processing batch 17
# → Batch 17 complete: 100000 records processed.
# Processing batch 18
# → Batch 18 complete: 100000 records processed.
# Processing batch 19
# → Batch 19 complete: 100000 records processed.
# Processing batch 20
# → Batch 20 complete: 100000 records processed.
# Processing batch 21
# → Batch 21 complete: 100000 records processed.
# Processing batch 22
# → Batch 22 complete: 100000 records processed.
# Processing batch 23
# → Batch 23 complete: 100000 records processed.
# Processing batch 24
# → Batch 24 complete: 100000 records processed.
# Processing batch 25
# → Batch 25 complete: 100000 records processed.
# Processing batch 26
# → Batch 26 complete: 100000 records processed.
# Processing batch 27
# → Batch 27 complete: 100000 records processed.
# Processing batch 28
# → Batch 28 complete: 100000 records processed.
# Processing batch 29
# → Batch 29 complete: 100000 records processed.
# Processing batch 30
# → Batch 30 complete: 100000 records processed.
# Processing batch 31
# → Batch 31 complete: 100000 records processed.
# Processing batch 32
# → Batch 32 complete: 100000 records processed.
# Processing batch 33
# → Batch 33 complete: 100000 records processed.
# Processing batch 34
# → Batch 34 complete: 100000 records processed.
# Processing batch 35
# → Batch 35 complete: 100000 records processed.
# Processing batch 36
# → Batch 36 complete: 100000 records processed.
# Processing batch 37
# → Batch 37 complete: 100000 records processed.
# Processing batch 38
# → Batch 38 complete: 100000 records processed.
# Processing batch 39
# → Batch 39 complete: 100000 records processed.
# Processing batch 40
# → Batch 40 complete: 100000 records processed.
# Processing batch 41
# → Batch 41 complete: 100000 records processed.
# Processing batch 42
# → Batch 42 complete: 100000 records processed.
# Processing batch 43
# → Batch 43 complete: 100000 records processed.
# Processing batch 44
# → Batch 44 complete: 100000 records processed.
# Processing batch 45
# → Batch 45 complete: 100000 records processed.
# Processing batch 46
# → Batch 46 complete: 100000 records processed.
# Processing batch 47
# → Batch 47 complete: 100000 records processed.
# Processing batch 48
# → Batch 48 complete: 100000 records processed.
# Processing batch 49
# → Batch 49 complete: 100000 records processed.
# Processing batch 50
# → Batch 50 complete: 100000 records processed.
# Processing batch 51
# → Batch 51 complete: 100000 records processed.
# Processing batch 52
# → Batch 52 complete: 100000 records processed.
# Processing batch 53
# → Batch 53 complete: 100000 records processed.
# Processing batch 54
# → Batch 54 complete: 100000 records processed.
# Processing batch 55
# → Batch 55 complete: 100000 records processed.
# Processing batch 56
# → Batch 56 complete: 100000 records processed.
# Processing batch 57
# → Batch 57 complete: 100000 records processed.
# Processing batch 58
# → Batch 58 complete: 100000 records processed.
# Processing batch 59
# → Batch 59 complete: 100000 records processed.
# Processing batch 60
# → Batch 60 complete: 100000 records processed.
# Processing batch 61
# → Batch 61 complete: 100000 records processed.
# Processing batch 62
# → Batch 62 complete: 100000 records processed.
# Processing batch 63
# → Batch 63 complete: 100000 records processed.
# Processing batch 64
# → Batch 64 complete: 100000 records processed.
# Processing batch 65
# → Batch 65 complete: 100000 records processed.
# Processing batch 66
# → Batch 66 complete: 100000 records processed.
# Processing batch 67
# → Batch 67 complete: 100000 records processed.
# Processing batch 68
# → Batch 68 complete: 100000 records processed.
# Processing batch 69
# → Batch 69 complete: 100000 records processed.
# Processing batch 70
# → Batch 70 complete: 100000 records processed.
# Processing batch 71
# → Batch 71 complete: 100000 records processed.
# Processing batch 72
# → Batch 72 complete: 100000 records processed.
# Processing batch 73
# → Batch 73 complete: 100000 records processed.
# Processing batch 74
# → Batch 74 complete: 100000 records processed.
# Processing batch 75
# → Batch 75 complete: 100000 records processed.
# Processing batch 76
# → Batch 76 complete: 100000 records processed.
# Processing batch 77
# → Batch 77 complete: 100000 records processed.
# Processing batch 78
# → Batch 78 complete: 100000 records processed.
# Processing batch 79
# → Batch 79 complete: 100000 records processed.
# Processing batch 80
# → Batch 80 complete: 100000 records processed.
# Processing batch 81
# → Batch 81 complete: 100000 records processed.
# Processing batch 82
# → Batch 82 complete: 100000 records processed.
# Processing batch 83
# → Batch 83 complete: 100000 records processed.
# Processing batch 84
# → Batch 84 complete: 100000 records processed.
# Processing batch 85
# → Batch 85 complete: 100000 records processed.
# Processing batch 86
# → Batch 86 complete: 100000 records processed.
# Processing batch 87
# → Batch 87 complete: 100000 records processed.
# Processing batch 88
# → Batch 88 complete: 100000 records processed.
# Processing batch 89
# → Batch 89 complete: 100000 records processed.
# Processing batch 90
# → Batch 90 complete: 100000 records processed.
# Processing batch 91
# → Batch 91 complete: 100000 records processed.
# Processing batch 92
# → Batch 92 complete: 100000 records processed.
# Processing batch 93
# → Batch 93 complete: 100000 records processed.
# Processing batch 94
# → Batch 94 complete: 100000 records processed.
# Processing batch 95
# → Batch 95 complete: 100000 records processed.
# Processing batch 96
# → Batch 96 complete: 100000 records processed.
# Processing batch 97
# → Batch 97 complete: 100000 records processed.
# Processing batch 98
# → Batch 98 complete: 100000 records processed.
# Processing batch 99
# → Batch 99 complete: 100000 records processed.
# Processing batch 100
# → Batch 100 complete: 100000 records processed.
# Processing batch 101
# → Batch 101 complete: 100000 records processed.
# Processing batch 102
# → Batch 102 complete: 100000 records processed.
# Processing batch 103
# → Batch 103 complete: 100000 records processed.
# Processing batch 104
# → Batch 104 complete: 100000 records processed.
# Processing batch 105
# → Batch 105 complete: 100000 records processed.
# Processing batch 106
# → Batch 106 complete: 100000 records processed.
# Processing batch 107
# → Batch 107 complete: 100000 records processed.
# Processing batch 108
# → Batch 108 complete: 100000 records processed.
# Processing batch 109
# → Batch 109 complete: 100000 records processed.
# Processing batch 110
# → Batch 110 complete: 100000 records processed.
# Processing batch 111
# → Batch 111 complete: 100000 records processed.
# Processing batch 112
# → Batch 112 complete: 100000 records processed.
# Processing batch 113
# → Batch 113 complete: 100000 records processed.
# Processing batch 114
# → Batch 114 complete: 100000 records processed.
# Processing batch 115
# → Batch 115 complete: 100000 records processed.
# Processing batch 116
# → Batch 116 complete: 100000 records processed.
# Processing batch 117
# → Batch 117 complete: 100000 records processed.
# Processing batch 118
# → Batch 118 complete: 100000 records processed.
# Processing batch 119
# → Batch 119 complete: 100000 records processed.
# Processing batch 120
# → Batch 120 complete: 100000 records processed.
# Processing batch 121
# → Batch 121 complete: 100000 records processed.
# Processing batch 122
# → Batch 122 complete: 100000 records processed.
# Processing batch 123
# → Batch 123 complete: 100000 records processed.
# Processing batch 124
# → Batch 124 complete: 100000 records processed.
# Processing batch 125
# → Batch 125 complete: 100000 records processed.
# Processing batch 126
# → Batch 126 complete: 100000 records processed.
# Processing batch 127
# → Batch 127 complete: 100000 records processed.
# Processing batch 128
# → Batch 128 complete: 100000 records processed.
# Processing batch 129
# → Batch 129 complete: 100000 records processed.
# Processing batch 130
# → Batch 130 complete: 100000 records processed.
# Processing batch 131
# → Batch 131 complete: 100000 records processed.
# Processing batch 132
# → Batch 132 complete: 100000 records processed.
# Processing batch 133
# → Batch 133 complete: 100000 records processed.
# Processing batch 134
# → Batch 134 complete: 80122 records processed.
#
# ✅ All done! Total enriched records: 13380122

# %%
df.head(20)
# Out:
#    vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0          VTS  2009-01-04 02:52:00   2009-01-04 03:02:00                1
# 1          VTS  2009-01-04 03:31:00   2009-01-04 03:38:00                3
# 2          VTS  2009-01-03 15:43:00   2009-01-03 15:57:00                5
# 3          DDS  2009-01-01 20:52:58   2009-01-01 21:14:00                1
# 4          DDS  2009-01-24 16:18:23   2009-01-24 16:24:56                1
# 5          DDS  2009-01-16 22:35:59   2009-01-16 22:43:35                2
# 6          DDS  2009-01-21 08:55:57   2009-01-21 09:05:42                1
# 7          VTS  2009-01-04 04:31:00   2009-01-04 04:36:00                1
# 8          CMT  2009-01-05 16:29:02   2009-01-05 16:40:21                1
# 9          CMT  2009-01-05 18:53:13   2009-01-05 18:57:45                1
# 10         CMT  2009-01-05 08:15:38   2009-01-05 08:16:44                1
# 11         CMT  2009-01-05 06:21:43   2009-01-05 06:28:41                1
# 12         DDS  2009-01-20 13:44:02   2009-01-20 13:52:43                2
# 13         CMT  2009-01-05 16:19:53   2009-01-05 16:26:48                2
# 14         CMT  2009-01-05 17:22:16   2009-01-05 17:27:25                1
# 15         CMT  2009-01-05 16:02:52   2009-01-05 16:18:43                1
# 16         CMT  2009-01-05 12:15:06   2009-01-05 12:27:58                1
# 17         CMT  2009-01-05 07:49:57   2009-01-05 07:54:11                1
# 18         DDS  2009-01-23 23:57:34   2009-01-24 00:12:40                2
# 19         CMT  2009-01-05 10:23:13   2009-01-05 10:33:56                1
#
#     Trip_Distance  start_lon  start_lat  Rate_Code  store_and_forward  \
# 0            2.63 -73.991957  40.721567        NaN                NaN
# 1            4.55 -73.982102  40.736290        NaN                NaN
# 2           10.35 -74.002587  40.739748        NaN                NaN
# 3            5.00 -73.974267  40.790955        NaN                NaN
# 4            0.40 -74.001580  40.719382        NaN                NaN
# 5            1.20 -73.989806  40.735006        NaN                NaN
# 6            0.40 -73.984050  40.743544        NaN                NaN
# 7            1.72 -73.992635  40.748362        NaN                NaN
# 8            1.60 -73.969690  40.749244        NaN                NaN
# 9            0.70 -73.955173  40.783044        NaN                NaN
# 10           0.30 -73.986824  40.750893        NaN                NaN
# 11           2.30 -74.006100  40.748432        NaN                NaN
# 12           2.10 -73.983339  40.744782        NaN                NaN
# 13           1.20 -73.973510  40.760280        NaN                NaN
# 14           0.80 -73.984426  40.757480        NaN                NaN
# 15           4.50 -73.991064  40.727654        NaN                NaN
# 16           1.70 -74.001678  40.747300        NaN                NaN
# 17           1.00 -73.982457  40.731475        NaN                NaN
# 18           5.00 -73.992554  40.724476        NaN                NaN
# 19           1.30 -73.990089  40.759027        NaN                NaN
#
#       end_lon  ...  Fare_Amt surcharge  mta_tax  Tip_Amt  Tolls_Amt  \
# 0  -73.993803  ...       8.9       0.5      NaN     0.00        0.0
# 1  -73.955850  ...      12.1       0.5      NaN     2.00        0.0
# 2  -73.869983  ...      23.7       0.0      NaN     4.74        0.0
# 3  -73.996558  ...      14.9       0.5      NaN     3.05        0.0
# 4  -74.008378  ...       3.7       0.0      NaN     0.00        0.0
# 5  -73.985021  ...       6.1       0.5      NaN     0.00        0.0
# 6  -73.980260  ...       5.7       0.0      NaN     1.00        0.0
# 7  -73.995585  ...       6.1       0.5      NaN     0.00        0.0
# 8  -73.990413  ...       8.7       0.0      NaN     1.30        0.0
# 9  -73.958598  ...       5.9       0.0      NaN     0.00        0.0
# 10 -73.984118  ...       2.9       0.0      NaN     0.00        0.0
# 11 -73.978437  ...       7.7       0.0      NaN     0.00        0.0
# 12 -73.981160  ...       7.3       0.0      NaN     0.00        0.0
# 13 -73.962933  ...       6.7       0.0      NaN     0.00        0.0
# 14 -73.982519  ...       5.9       0.0      NaN     0.00        0.0
# 15 -73.945771  ...      13.9       0.0      NaN     0.00        0.0
# 16 -73.978957  ...       8.5       0.0      NaN     0.00        0.0
# 17 -73.973011  ...       4.5       0.0      NaN     1.00        0.0
# 18 -73.953065  ...      13.3       0.5      NaN     3.45        0.0
# 19 -73.983974  ...       7.3       0.0      NaN     0.00        0.0
#
#     Total_Amt                    start_zone  start_borough  \
# 0        9.40               Lower East Side      Manhattan
# 1       14.60                      Gramercy      Manhattan
# 2       28.44                  West Village      Manhattan
# 3       18.45         Upper West Side North      Manhattan
# 4        3.70           Little Italy/NoLiTa      Manhattan
# 5        6.60                      Gramercy      Manhattan
# 6        6.70                 Midtown South      Manhattan
# 7        6.60  Penn Station/Madison Sq West      Manhattan
# 8       10.00           UN/Turtle Bay South      Manhattan
# 9        5.90         Upper East Side North      Manhattan
# 10       2.90                 Midtown South      Manhattan
# 11       7.70     West Chelsea/Hudson Yards      Manhattan
# 12       7.30                 Midtown South      Manhattan
# 13       6.70                Midtown Center      Manhattan
# 14       5.90     Times Sq/Theatre District      Manhattan
# 15      13.90                  East Village      Manhattan
# 16       8.50                  East Chelsea      Manhattan
# 17       5.50                      Gramercy      Manhattan
# 18      17.25       Greenwich Village South      Manhattan
# 19       7.30                  Clinton East      Manhattan
#
#                    end_zone end_borough
# 0          Brooklyn Heights    Brooklyn
# 1           Lenox Hill West   Manhattan
# 2             East Elmhurst      Queens
# 3   Greenwich Village North   Manhattan
# 4      TriBeCa/Civic Center   Manhattan
# 5              East Village   Manhattan
# 6               Murray Hill   Manhattan
# 7   Greenwich Village South   Manhattan
# 8          Garment District   Manhattan
# 9     Upper East Side North   Manhattan
# 10            Midtown South   Manhattan
# 11           Midtown Center   Manhattan
# 12            Alphabet City   Manhattan
# 13    Upper East Side North   Manhattan
# 14            Midtown North   Manhattan
# 15           Yorkville East   Manhattan
# 16              Murray Hill   Manhattan
# 17                 Kips Bay   Manhattan
# 18           Yorkville West   Manhattan
# 19            Midtown South   Manhattan
#
# [20 rows x 22 columns]

# %%
df.to_parquet('yellow_tripdata_2009-02_enriched.parquet', index=False)
print("✅ Exported to yellow_tripdata_2009-02_enriched.parquet")
# Out:
# ✅ Exported to yellow_tripdata_2009-02_enriched.parquet

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14092413 entries, 0 to 14092412
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendor_name            object
#  1   Trip_Pickup_DateTime   object
#  2   Trip_Dropoff_DateTime  object
#  3   Passenger_Count        int64
#  4   Trip_Distance          float64
#  5   Start_Lon              float64
#  6   Start_Lat              float64
#  7   Rate_Code              float64
#  8   store_and_forward      float64
#  9   End_Lon                float64
#  10  End_Lat                float64
#  11  Payment_Type           object
#  12  Fare_Amt               float64
#  13  surcharge              float64
#  14  mta_tax                float64
#  15  Tip_Amt                float64
#  16  Tolls_Amt              float64
#  17  Total_Amt              float64
# dtypes: float64(13), int64(1), object(4)
# memory usage: 1.9+ GB
# None

# %%
count_non_null = df['Rate_Code'].count()
print("Number of non-null rate_code values in first 20 rows:", count_non_null)
# Out:
# Number of non-null rate_code values in first 20 rows: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14092413 entries, 0 to 14092412
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendor_name            object
#  1   Trip_Pickup_DateTime   object
#  2   Trip_Dropoff_DateTime  object
#  3   Passenger_Count        int64
#  4   Trip_Distance          float64
#  5   Start_Lon              float64
#  6   Start_Lat              float64
#  7   Rate_Code              float64
#  8   store_and_forward      float64
#  9   End_Lon                float64
#  10  End_Lat                float64
#  11  Payment_Type           object
#  12  Fare_Amt               float64
#  13  surcharge              float64
#  14  mta_tax                float64
#  15  Tip_Amt                float64
#  16  Tolls_Amt              float64
#  17  Total_Amt              float64
# dtypes: float64(13), int64(1), object(4)
# memory usage: 1.9+ GB
